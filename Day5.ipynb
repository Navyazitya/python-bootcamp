# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.array([0,1,2,3])
y=np.array([2,3,4,5])

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y)
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,'o')
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,'x')
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,'*')
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,marker='o',linestyle='dashed')
plt.show()

# %%
x=np.array([56,67,34,56,89])
y=np.array([2,54,88,33,11])

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,marker='o',linestyle='dashed')
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,marker='o',ls='dashed')
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,marker='o',ls=':')
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,marker='o',ls=':')

plt.title('cutie')
plt.xlabel('patootie')
plt.ylabel('immortal')
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,marker='o',ls=':',mfc='pink',mec='red')

plt.title('cutie')
plt.xlabel('patootie')
plt.ylabel('immortal')
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,marker='o',ls=':',mfc='pink',mec='#ff33eb')

plt.title('cutie')
plt.xlabel('patootie')
plt.ylabel('immortal')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,marker='o',ls=':',mfc='pink',mec='red')

plt.title('cutie')
plt.xlabel('patootie')
plt.ylabel('immortal')
plt.grid(color='green')
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,marker='o',ls=':',mfc='pink',mec='red')

plt.title('cutie')
plt.xlabel('patootie')
plt.ylabel('immortal')
plt.grid(color='green',ls=':',linewidth=0.2)
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.plot(x, y,marker='o',ls=':',mfc='pink',mec='red')

plt.title('cutie')
plt.xlabel('patootie')
plt.ylabel('immortal')
plt.grid(color='#ff33eb',ls=':',linewidth=0.2)
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x)

plt.subplot(1,2,2)
plt.plot(y)

plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x)

plt.subplot(2,1,2)
plt.plot(y)

plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(y,marker='o', ls = ':', mfc='pink', mec='red',color = '#ff33eb')

plt.subplot(1,2,2)
plt.plot(x,marker='o', ls = ':', mfc='pink', mec='red',color = '#ff33eb')

plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x)
plt.title('cutie')

plt.subplot(2,1,2)
plt.plot(y)
plt.title('patotie')

plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(y,marker='o', ls = ':', mfc='pink', mec='red',color = '#ff33eb')
plt.title('cutie')

plt.subplot(1,2,2)
plt.plot(x,marker='o', ls = ':', mfc='pink', mec='red',color = '#ff33eb')
plt.title('patootie')

plt.suptitle('naruto')
plt.legend()

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x1=np.array([4,5,7,8,9,3,1,2,3,4])
y1=np.array([5,4,8,6,9,5,2,4,5,9,])
plt.bar(x1,y1,color='hotpink',width=0.8)
plt.show()

# %%
x1=np.array([4,5,7,8,9,3,1,2,3,4])
y1=np.array([5,4,8,6,9,5,2,4,5,9,])
plt.bar(x1,y1,color='hotpink',width=0.8)
plt.title('cutie')
plt.xlabel('patootie')
plt.ylabel('immortal')
plt.show()

# %%
x1=np.array([4,5,7,8,9,3,1,2,3,4])
y1=np.array([5,4,8,6,9,5,2,4,5,9,])
plt.barh(x1,y1)
plt.title('cutie')
plt.xlabel('patootie')
plt.ylabel('immortal')
plt.show()

# %%
x=np.array([1,2,7,8,5,3,1,4,3,5])
y=np.array([5,4,6,6,9,5,2,2,3,3,])
x1=np.array([4,5,7,8,9,3,1,2,3,4])
y1=np.array([5,4,8,6,9,5,2,4,5,9,])
plt.scatter(x,y)

# %%
plt.scatter(x,y,label='minato',color='yellow')
plt.scatter(x1,y1,label='madara',color='green')
plt.show()

# %%
plt.scatter(x,y,label='minato',color='yellow')
plt.scatter(x1,y1,label='madara',color='green')

plt.title('ninja',fontsize=15)
plt.xlabel('patootie')
plt.ylabel('immortal')
plt.show()

# %%
plt.scatter(x,y,label='minato',color='yellow')
plt.scatter(x1,y1,label='madara',color='green')
plt.title('ninja',fontsize=15)
plt.xlabel('patootie')
plt.ylabel('immortal')
plt.show()

# %%
nav=np.array([0,10,20,30,40,50,60,70,80,100])
plt.scatter(x,y,c=nav,cmap='Blues')
plt.colorbar()
plt.show()

# %%
plt.hist(x)
# Out:
# (array([2., 1., 2., 0., 1., 2., 0., 0., 1., 1.]),
#  array([1. , 1.7, 2.4, 3.1, 3.8, 4.5, 5.2, 5.9, 6.6, 7.3, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(x)
plt.title('navya')
plt.show()

# %%
import seaborn as sns

# %%
sns.distplot(x)
# Out:
# <ipython-input-87-5ec1fbeebf40>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
# <Axes: ylabel='Density'>

# %%
df=pd.read_csv('/content/final.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_name', 'artist(s)_name', 'artist_count',
#        'released_year', 'released_month', 'released_day',
#        'in_spotify_playlists', 'in_spotify_charts', 'streams',
#        'in_apple_charts'],
#       dtype='object')

# %%
sns.countplot(x='released_day', data = df)
plt.show()

# %%
sns.scatterplot(y='in_spotify_playlists', x= 'in_spotify_charts', data = df,  hue ='released_day' )
plt.show()

# %%
df1 = df.drop(['Unnamed: 0', 'track_name', 'artist(s)_name','streams'],axis = 1)

# %%
 x= df1.corr()
 sns.heatmap(x)
 plt.show()
